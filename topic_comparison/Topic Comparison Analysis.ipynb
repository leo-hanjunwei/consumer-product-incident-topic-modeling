# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# #### Import data

# %%
df = pd.read_excel("../../../Data/With_Topic/USCA_Topic.xlsx")
df.shape

# %% [markdown]
# #### None Topic Proportion

# %%
print(sum(pd.isnull(df["Topic_number"]))/df.shape[0])
print(sum(df["Topic_number"]==-1)/df.shape[0])
# Out:
# 0.0
# 0.0012769413248132674

# %% [markdown]
# #### Assign Topic Name

# %%
import warnings
warnings.filterwarnings('ignore')
df["Topic_name"]=np.nan
for i in range(df.shape[0]):
    if df["Topic_number"][i] == 1:
        df["Topic_name"].iloc[i] = "Fatal Special Viechle Accident"
    elif df["Topic_number"][i] == 2:
        df["Topic_name"].iloc[i] = "Stair Fall (Fall)"
    elif df["Topic_number"][i] == 3:
        df["Topic_name"].iloc[i] = "Small Part Hazard"
    elif df["Topic_number"][i] == 4:
        df["Topic_name"].iloc[i] = "Drowning asphyxia"
    elif df["Topic_number"][i] == 5:
        df["Topic_name"].iloc[i] = "Bedroom Hazard"
    elif df["Topic_number"][i] == 6:
        df["Topic_name"].iloc[i] = "Stop Words"
    elif df["Topic_number"][i] == 7:
        df["Topic_name"].iloc[i] = "Young Drown"
    elif df["Topic_number"][i] == 8:
        df["Topic_name"].iloc[i] = "Electric Assoseriate"
    elif df["Topic_number"][i] == 9:
        df["Topic_name"].iloc[i] = "Cooking Appliances"
    elif df["Topic_number"][i] == 10:
        df["Topic_name"].iloc[i] = "Garage Toxic Gas"
    elif df["Topic_number"][i] == 11:
        df["Topic_name"].iloc[i] = "Hip Fracture"
    elif df["Topic_number"][i] == 12:
        df["Topic_name"].iloc[i] = "Viechle"
    elif df["Topic_number"][i] == 13:
        df["Topic_name"].iloc[i] = "General CO Emission"
    elif df["Topic_number"][i] == 14:
        df["Topic_name"].iloc[i] = "Drown Death"
    elif df["Topic_number"][i] == 15:
        df["Topic_name"].iloc[i] = "Home Pool"
    elif df["Topic_number"][i] == 16:
        df["Topic_name"].iloc[i] = "Microwave"
    elif df["Topic_number"][i] == 17:
        df["Topic_name"].iloc[i] = "Glass"
    elif df["Topic_number"][i] == 18:
        df["Topic_name"].iloc[i] = "Asphyxia due to various causes"
    elif df["Topic_number"][i] == 19:
        df["Topic_name"].iloc[i] = "Snow Mobile"
    elif df["Topic_number"][i] == 20:
        df["Topic_name"].iloc[i] = "General House Fire"
    elif df["Topic_number"][i] == 21:
        df["Topic_name"].iloc[i] = "Diswasher and Overheat"
    elif df["Topic_number"][i] == 22:
        df["Topic_name"].iloc[i] = "Mower"
    elif df["Topic_number"][i] == 23:
        df["Topic_name"].iloc[i] = "Luminaire"
    elif df["Topic_number"][i] == 24:
        df["Topic_name"].iloc[i] = "Fire and Inhalation"
    elif df["Topic_number"][i] == 25:
        df["Topic_name"].iloc[i] = "General Fall"
    elif df["Topic_number"][i] == 26:
        df["Topic_name"].iloc[i] = "open flame"
    elif df["Topic_number"][i] == 27:
        df["Topic_name"].iloc[i] = "Ladder (electrocution) Fall (High)"
    elif df["Topic_number"][i] == 28:
        df["Topic_name"].iloc[i] = "Refrigerator"
    elif df["Topic_number"][i] == 29:
        df["Topic_name"].iloc[i] = "explosion"
    elif df["Topic_number"][i] == 30:
        df["Topic_name"].iloc[i] = "Fire place Accident"
    elif df["Topic_number"][i] == 31:
        df["Topic_name"].iloc[i] = "Skin Rash"
    elif df["Topic_number"][i] == 32:
        df["Topic_name"].iloc[i] = "Bath Drown"
    elif df["Topic_number"][i] == 33:
        df["Topic_name"].iloc[i] = "Swimming Pool Drown"
    elif df["Topic_number"][i] == 34:
        df["Topic_name"].iloc[i] = "Small Personal Electric Device and its accessories"
    elif df["Topic_number"][i] == 35:
        df["Topic_name"].iloc[i] = "kitchen fire"
    elif df["Topic_number"][i] == 36:
        df["Topic_name"].iloc[i] = "Sleeping asphyxia with guardian"
    elif df["Topic_number"][i] == 37:
        df["Topic_name"].iloc[i] = "Non-Home Pool"
    elif df["Topic_number"][i] == 38:
        df["Topic_name"].iloc[i] = "Non-Home Pool"
    elif df["Topic_number"][i] == 39:
        df["Topic_name"].iloc[i] = "Game Injury"
    elif df["Topic_number"][i] == 40:
        df["Topic_name"].iloc[i] = "Bicycle Accident"
    elif df["Topic_number"][i] == 41:
        df["Topic_name"].iloc[i] = "Wash Machine"
    elif df["Topic_number"][i] == 0:
        df["Topic_name"].iloc[i] = "Mobility"

# %%
sum(df["Topic_name"].isnull()) == sum(df["Topic_number"]==-1)
# Out:
# True

# %% [markdown]
# #### Unify Data

# %%
incidents = df[['Product_Code', 
                'Description', 
                'SEVERITY', 
                'Hazard', 
                'Injury', 
                'Body_part', 
                'Year',
                'Topic_number',
                'Topic_name']]

# %% [markdown]
# - Fatal Special Viechle Accident
# - Fire and Inhalation
# - Mobility *
# - Snow Mobile
# - Small Personal Electric Device and its accessories
# - Rash
# - Small Part Hazard
# - Electric Assoseriate
# - Mower
# - open flame
# - Fire place Accident
# - Dishwasher
# - Refrigerator

# %% [markdown]
# ### 1. Mobility (0)
# ---

# %%
Mobility = incidents[incidents["Topic_name"]=="Mobility"]
# Mobility.head()

# %% [markdown]
# #### Number of relevant incidents

# %%
sns.catplot(x='Year', kind='count' ,data=Mobility,  order = range(2013,2020))
plt.title('Incident number distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# ### Product Code

# %%
print(Mobility["Product_Code"].nunique())
pop = (Mobility["Product_Code"].value_counts()/len(Mobility["Product_Code"]))[0:5]
pop
# Out:
# 85
# 5040    0.722947
# 3215    0.065117
# 5042    0.042007
# 5036    0.025421
# 1522    0.023518
# Name: Product_Code, dtype: float64

# %% [markdown]
# - 5040 Bicycles or accessories
# - 3215 Mopeds or power-assisted cycles
# - 5042 Hoverboards
# - 5036 Two-wheeled, powered, off-road vehicles (incl. dirt bikes and trail bikes;  excl.          mopeds and minibikes)
# - 1522 Baby strollers

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = "Bicycles or accessories", "Mopeds or power-assisted cycles", "Hoverboards", "Two-wheeled, powered, off-road vehicles", "Baby strollers", "Other"
sizes = np.array([pop.iloc[0], pop.iloc[1], pop.iloc[2], pop.iloc[3], pop.iloc[4], 1- pop.sum()])

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
fig1.set_size_inches(10, 8)
plt.show()

# %% [markdown]
# #### Body part

# %%
## Body_part
sns.catplot(y='Body_part', kind='count' ,data=Mobility, order = list(Mobility['Body_part'].value_counts().index))
plt.title('Body_part distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %% [markdown]
# Top five are:
# * Other
# * Head
# * Leg
# * Trunk
# * Arm

# %% [markdown]
# #### Body part in time

# %%
td = Mobility[(Mobility["Body_part"]=="Head")|
              (Mobility["Body_part"]=="Other")|
              (Mobility["Body_part"]=="Leg")|
              (Mobility["Body_part"]=="Trunk")|
              (Mobility["Body_part"]=="Arm")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "Body_part", order = range(2013,2020))
plt.title('Body_part distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# * Increasing Trend for other
# * seasonal trend for Head

# %% [markdown]
# #### Injury

# %%
## Injury
sns.catplot(y='Injury', kind='count' ,data=Mobility, order = list(Mobility['Injury'].value_counts().index))
plt.title('Injury distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %% [markdown]
# Top five:
#    * Other
#    * Unknown
#    * Fracture
#    * Bruise/Scratch
#    * Cut

# %%
td = Mobility[(Mobility["Injury"]=="Other")|
              (Mobility["Injury"]=="Unknown")|
              (Mobility["Injury"]=="Fracture")|
              (Mobility["Injury"]=="Bruise/Scratch")|
              (Mobility["Injury"]=="Cut")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "Injury", order = range(2013,2020))
plt.title('Injury distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# * Other Increasing

# %% [markdown]
# #### Hazard

# %%
## Hazard
sns.catplot(y='Hazard', kind='count' ,data=Mobility, order = list(Mobility['Hazard'].value_counts().index))
plt.title('Hazard distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# plt.savefig('Region_distribution.png')

# %% [markdown]
# Top five:
#    * Struck By/Against
#    * Slip/Fail
#    * Tip Over / Instability
#    * Mechanical-Other
#    * Electrical

# %%
td = Mobility[(Mobility["Hazard"]=="Struck By/Against")|
              (Mobility["Hazard"]=="Slip/Fall")|
              (Mobility["Hazard"]=="Tip Over / Instability")|
              (Mobility["Hazard"]=="Mechanical-Other")|
              (Mobility["Hazard"]=="Electrical")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "Hazard", order = range(2013,2020))
plt.title('Hazard distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# * Struck By/Against gradually increase
# * Very similar to the overall trend

# %%
## Severity
sns.catplot(y='SEVERITY', kind='count' ,data=Mobility, order = list(Mobility['SEVERITY'].value_counts().index))
plt.title('SEVERITY distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %%
td = Mobility[(Mobility["SEVERITY"]=="Hospitalization")|
              (Mobility["SEVERITY"]=="Fatality")|
              (Mobility["SEVERITY"]=="Injury Requiring Medical Attention")|
              (Mobility["SEVERITY"]=="No Injury")|
              (Mobility["SEVERITY"]=="Unknown")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "SEVERITY", order = range(2013,2020))
plt.title('SEVERITY distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# - Increase of hospitalization

# %% [markdown]
# ### 2. Skin Rash (31)

# %%
Skin_Rash = incidents[incidents["Topic_name"]=="Skin Rash"]
# Skin_Rash.head()

# %% [markdown]
# #### Incident Distribution

# %%
sns.catplot(x='Year', kind='count' ,data=Skin_Rash,  order = range(2013,2020))
plt.title('Incident Number distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# - Seasonal
# - two peaks (2014 and 2017)

# %% [markdown]
# #### Product Code

# %%
print(Skin_Rash["Product_Code"].nunique())
pop = (Skin_Rash["Product_Code"].value_counts()/len(Skin_Rash["Product_Code"]))[0:5]
pop
# Out:
# 271
# 557     0.153537
# 1512    0.095459
# 1913    0.093914
# 0       0.071053
# 949     0.050973
# Name: Product_Code, dtype: float64

# %% [markdown]
# - 557 Computers (equipment and electronic games)
# - 1512 Diapers
# - 1913 Cosmetics (Eye make-up)
# - 0 No record
# - 949 Laundry soaps or detergents

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = "Computers", "Diapers", "Cosmetics (Eye make-up)", "No record", "Laundry soaps or detergents", "Other"
sizes = np.array([pop.iloc[0], pop.iloc[1], pop.iloc[2], pop.iloc[3], pop.iloc[4], 1- pop.sum()])

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
fig1.set_size_inches(10, 8)
plt.show()

# %% [markdown]
# #### Body Part

# %%
## Body_part
sns.catplot(y='Body_part', kind='count' ,data=Skin_Rash, order = list(Skin_Rash['Body_part'].value_counts().index))
plt.title('Body_part distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %% [markdown]
# Top five:
# * Wrist
# * Other
# * Finger
# * Trunk
# * Public Region

# %%
td = Skin_Rash[(Skin_Rash["Body_part"]=="Wrist")|
               (Skin_Rash["Body_part"]=="Other")|
               (Skin_Rash["Body_part"]=="Finger")|
               (Skin_Rash["Body_part"]=="Trunk")|
               (Skin_Rash["Body_part"]=="Public Region")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "Body_part", order = range(2013,2020))
plt.title('Body_part distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# In 2013, wrist is not a popular body part.
#
# however after that, wrist sudenly become very popular and gradually decreased.
#
# Proof of fitbit Phenomenon

# %% [markdown]
# #### Hazard

# %%
## Hazard
sns.catplot(y='Hazard', kind='count' ,data=Skin_Rash, order = list(Skin_Rash['Hazard'].value_counts().index))
plt.title('Hazard distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %% [markdown]
# Top 5:
# * Other
# * Toxic Substance
# * Sharp/Pointed Object
# * Small Part
# * Electrical

# %%
td = Skin_Rash[(Skin_Rash["Hazard"]=="Toxic Substance")|
               (Skin_Rash["Hazard"]=="Other")|
               (Skin_Rash["Hazard"]=="Sharp/Pointed Object")|
               (Skin_Rash["Hazard"]=="Small Part")|
               (Skin_Rash["Hazard"]=="Electrical")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "Hazard", order = range(2013,2020))
plt.title('Hazard distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# Other decrease
#
# Toxic Substance

# %% [markdown]
# #### Injury

# %%
## Injury
sns.catplot(y='Injury', kind='count' ,data=Skin_Rash, order = list(Skin_Rash['Injury'].value_counts().index))
plt.title('Injury distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %%
Skin_Rash["Injury"].unique()
# Out:
# array([nan, 'Cut', 'Unknown', 'Other', 'Burn',
#        'Irritation or Allergic reaction', 'Poisoning', 'Bruise/Scratch',
#        'Amputation', 'Foreign Object', 'Shock', 'Asphyxia', 'Fracture',
#        'Strain/Sprain'], dtype=object)

# %% [markdown]
# * Irritation or Allergic reaction
# * Cut
# * Burn
# * Unknown
# * Other

# %%
td = Skin_Rash[(Skin_Rash["Injury"]=="Irritation or Allergic reaction")|
               (Skin_Rash["Injury"]=="Cut")|
               (Skin_Rash["Injury"]=="Burn")|
               (Skin_Rash["Injury"]=="Unknown")|
               (Skin_Rash["Injury"]=="Other")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "Injury", order = range(2013,2020))
plt.title('Injury distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# * Irritation or Allergic reaction (make sense) fitbit similar trend.

# %% [markdown]
# #### Severity

# %%
## SEVERITY
sns.catplot(y='SEVERITY', kind='count' ,data=Skin_Rash, order = list(Skin_Rash['SEVERITY'].value_counts().index))
plt.title('SEVERITY distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %%
Skin_Rash["SEVERITY"].unique()
# Out:
# array(['Unknown', 'No Injury', 'Fatality', 'First Aid only',
#        'Less than First Aid', 'Injury Requiring Medical Attention',
#        'Hospitalization', 'Less than  First Aid'], dtype=object)

# %%
td = Skin_Rash[(Skin_Rash["SEVERITY"]=="Injury Requiring Medical Attention")|
               (Skin_Rash["SEVERITY"]=="Unknown")|
               (Skin_Rash["SEVERITY"]=="First Aid only")|
               (Skin_Rash["SEVERITY"]=="Less than First Aid")|
               (Skin_Rash["SEVERITY"]=="No Injury")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "SEVERITY", order = range(2013,2020))
plt.title('SEVERITY distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# - Dramatic increase of Unknown in 2017
# - trend of injury requiring Medical Attension is similar to wrist in bodypart

# %% [markdown]
# ### 3. Refrigerator (29)

# %%
Refrigerator = incidents[incidents["Topic_name"]=="Refrigerator"]
# Refrigerator.head()

# %% [markdown]
# #### Incidents Distribution

# %%
sns.catplot(x='Year', kind='count' ,data=Refrigerator,  order = range(2013,2020))
plt.title('Incident Number distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# No obvious trend

# %% [markdown]
# #### Product Code

# %%
print(Refrigerator["Product_Code"].nunique())
pop = (Refrigerator["Product_Code"].value_counts()/len(Refrigerator["Product_Code"]))[0:5]
pop
# Out:
# 115
# 276    0.674941
# 275    0.060875
# 306    0.028369
# 215    0.024823
# 263    0.020095
# Name: Product_Code, dtype: float64

# %% [markdown]
# - 276 Refrigerators
# - 275 Food processors
# - 306 Dehumidifiers
# - 215 Blenders
# - 263 Freezers (separate from refrigerators)Appendix H: Numerical Listing of NEISS Product Codes

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = "Refrigerators", "Food processors", "Dehumidifiers", "Blenders", "Freezers", "Other"
sizes = np.array([pop.iloc[0], pop.iloc[1], pop.iloc[2], pop.iloc[3], pop.iloc[4], 1- pop.sum()])

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
fig1.set_size_inches(10, 8)
plt.show()

# %% [markdown]
# #### Body Part

# %%
## Body_part
sns.catplot(y='Body_part', kind='count' ,data=Refrigerator, order = list(Refrigerator['Body_part'].value_counts().index))
plt.title('Body_part distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %%
td = Refrigerator[(Refrigerator["Body_part"]=="Other")|
               (Refrigerator["Body_part"]==">50% of Body")|
               (Refrigerator["Body_part"]=="Finger")|
               (Refrigerator["Body_part"]=="Hand")|
               (Refrigerator["Body_part"]=="Head")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "Body_part", order = range(2013,2020))
plt.title('Body_part distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# Other increases, (is other means no body part involve?)

# %% [markdown]
# #### Hazard

# %%
## Hazard
sns.catplot(y='Hazard', kind='count' ,data=Refrigerator, order = list(Refrigerator['Hazard'].value_counts().index))
plt.title('Hazard distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %%
td = Refrigerator[(Refrigerator["Hazard"]=="Electrical")|
               (Refrigerator["Hazard"]=="Sharp/Pointed Object")|
               (Refrigerator["Hazard"]=="Small Part")|
               (Refrigerator["Hazard"]=="Toxic Substance")|
               (Refrigerator["Hazard"]=="Other")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "Hazard", order = range(2013,2020))
plt.title('Hazard distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# - Sharp suddenly increasing in 2016
# - electrical decrease

# %% [markdown]
# #### Injury

# %%
## Injury
sns.catplot(y='Injury', kind='count' ,data=Refrigerator, order = list(Refrigerator['Injury'].value_counts().index))
plt.title('Injury distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %%
td = Refrigerator[(Refrigerator["Injury"]=="Unknown")|
               (Refrigerator["Injury"]=="Cut")|
               (Refrigerator["Injury"]=="Other")|
               (Refrigerator["Injury"]=="Poisoning")|
               (Refrigerator["Injury"]=="Burn")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "Injury", order = range(2013,2020))
plt.title('Injury distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# * Unknown increase
# * Cut increasing in 2015

# %%
## SEVERITY
sns.catplot(y='SEVERITY', kind='count' ,data=Refrigerator, order = list(Refrigerator['SEVERITY'].value_counts().index))
plt.title('SEVERITY distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %%
Refrigerator["SEVERITY"].unique()
# Out:
# array(['Unknown', 'No Injury', 'Injury Requiring Medical Attention',
#        'Less than First Aid', 'Less than  First Aid', 'First Aid only',
#        'Hospitalization', 'Fatality'], dtype=object)

# %%
td = Refrigerator[(Refrigerator["SEVERITY"]=="No Injury")|
               (Refrigerator["SEVERITY"]=="Unknown")|
               (Refrigerator["SEVERITY"]=="Less than  First Aid")|
               (Refrigerator["SEVERITY"]=="First Aid only")|
               (Refrigerator["SEVERITY"]=="Injury Requiring Medical Attention")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "SEVERITY", order = range(2013,2020))
plt.title('SEVERITY distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# * Most are not injured
# * unknown decreasing

# %% [markdown]
# ### 4. Diswasher and Overheat (21)

# %%
Diswasher_and_Overheat = incidents[incidents["Topic_name"]=="Diswasher and Overheat"]
# Diswasher_and_Overheat.head()

# %%
sns.catplot(x='Year', kind='count' ,data=Diswasher_and_Overheat,  order = range(2013,2020))
plt.title('Incident Number distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# No obvious trend (Decreasing?)

# %% [markdown]
# #### Product Code

# %%
print(Diswasher_and_Overheat["Product_Code"].nunique())
pop = (Diswasher_and_Overheat["Product_Code"].value_counts()/len(Diswasher_and_Overheat["Product_Code"]))[0:5]
pop
# Out:
# 174
# 214     0.588301
# 217     0.039745
# 474     0.030746
# 140     0.022872
# 1537    0.015373
# Name: Product_Code, dtype: float64

# %% [markdown]
# - 214 Dishwashers
# - 217 Electric coffee makers or teapots
# - 474 Tableware and accessories (excluding drinking glasses, cups, and mugs)
# - 140 Washing machines, other or not specified
# - 1537 Bassinets or cradles

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = "Dishwashers", "Electric coffee makers or teapots", "Tableware and accessories", "Washing machines, other or not specified", "Bassinets or cradles", "Other"
sizes = np.array([pop.iloc[0], pop.iloc[1], pop.iloc[2], pop.iloc[3], pop.iloc[4], 1- pop.sum()])

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
fig1.set_size_inches(10, 8)
plt.show()

# %%
## Body_part
sns.catplot(y='Body_part', kind='count' ,data=Diswasher_and_Overheat, order = list(Diswasher_and_Overheat['Body_part'].value_counts().index))
plt.title('Body_part distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %%
td = Diswasher_and_Overheat[(Diswasher_and_Overheat["Body_part"]=="Other")|
               (Diswasher_and_Overheat["Body_part"]=="Hand")|
               (Diswasher_and_Overheat["Body_part"]=="Finger")|
               (Diswasher_and_Overheat["Body_part"]==">50% of Body")|
               (Diswasher_and_Overheat["Body_part"]=="Leg")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "Body_part", order = range(2013,2020))
plt.title('Injury distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# Is other means no injury? Product defect

# %% [markdown]
# #### Hazard

# %%
## Hazard
sns.catplot(y='Hazard', kind='count' ,data=Diswasher_and_Overheat, order = list(Diswasher_and_Overheat['Hazard'].value_counts().index))
plt.title('Hazard distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %%
td = Diswasher_and_Overheat[(Diswasher_and_Overheat["Hazard"]=="Electrical")|
               (Diswasher_and_Overheat["Hazard"]=="Sharp/Pointed Object")|
               (Diswasher_and_Overheat["Hazard"]=="Other")|
               (Diswasher_and_Overheat["Hazard"]=="Thermal-Other")|
               (Diswasher_and_Overheat["Hazard"]=="Toxic Substance")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "Hazard", order = range(2013,2020))
plt.title('Hazard distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# * Electrical decreasing
# * Electrical have the highest proportion

# %% [markdown]
# #### Injury

# %%
## Injury
sns.catplot(y='Injury', kind='count' ,data=Diswasher_and_Overheat, order = list(Diswasher_and_Overheat['Injury'].value_counts().index))
plt.title('Injury distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %%
td = Diswasher_and_Overheat[(Diswasher_and_Overheat["Injury"]=="Unknown")|
               (Diswasher_and_Overheat["Injury"]=="Cut")|
               (Diswasher_and_Overheat["Injury"]=="Burn")|
               (Diswasher_and_Overheat["Injury"]=="Other")|
               (Diswasher_and_Overheat["Injury"]=="Poisoning")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "Injury", order = range(2013,2020))
plt.title('Injury distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# Burn Suddenly increase in 2014 and there is a second peak in 2018
#
# Cut increase and decrease

# %%
## SEVERITY
sns.catplot(y='SEVERITY', kind='count' ,data=Diswasher_and_Overheat, order = list(Diswasher_and_Overheat['SEVERITY'].value_counts().index))
plt.title('SEVERITY distribution')

fig = plt.gcf()
fig.set_size_inches(12, 6)

# %%
td = Diswasher_and_Overheat[(Diswasher_and_Overheat["SEVERITY"]=="No Injury")|
               (Diswasher_and_Overheat["SEVERITY"]=="Unknown")|
               (Diswasher_and_Overheat["SEVERITY"]=="Less than  First Aid")|
               (Diswasher_and_Overheat["SEVERITY"]=="First Aid only")|
               (Diswasher_and_Overheat["SEVERITY"]=="Injury Requiring Medical Attention")]
sns.catplot(x='Year', kind='count' ,data=td, hue = "SEVERITY", order = range(2013,2020))
plt.title('SEVERITY distribution')

fig = plt.gcf()
fig.set_size_inches(18, 6)

# %% [markdown]
# Most are not injured
# decreasing of no injury and unknown

# %% [markdown]
# - spectrum
# - condition topic and product topic
#     - maybe not good by just name a topic with the majority product.
